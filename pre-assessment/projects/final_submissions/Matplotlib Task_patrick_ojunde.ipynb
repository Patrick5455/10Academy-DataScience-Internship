# %% [markdown]
# # Matplolib Task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
plt.style.use('seaborn')

# %%
data = pd.read_csv("pandas_tasks.csv")
data.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %% [markdown]
# ## Instruction

# %% [markdown]
# * Using the loaded dataset, make a boxplot, barplot, histogram, and a scatter plot.
# * Ensure to provide appropriate labels, and titles where necessary.
# * In each plot, ensure to use all parameters used in the Matplolib tutorial.
# * Optionally, add additional parameters for each plot for some extra points.
# * For each of the plot, choose appropriate columns in the dataset. The explanation for each of the variables has been provided in a word document called `Variable_Codebook.docx`.

# %% [markdown]
# > Provide appropriate labesl to columns

# %%
rename_columns = {'Q1':'age',
 'Q2':'gender',
 'Q3':'highest_eduction',
 'Q4':'land_response',
 'Q6':'own_land',
 'Q7':'own_phone',
 'Q9':'employer',
 'Q10':'goods_sold',
 'Q11':'service_provided',
 'Q12':'sent_money_outside',
 'Q13':'sent_money_last',
 'Q14':'recived_money_inlast12months',
 'Q15':'last_recieved_money',
 'Q16':'purchase_frequency',
 'Q17':'bills_frequency',
 'Q18':'kiswahili_literacy',
 'Q19':'english_literacy'}

# %%
data.rename(columns=rename_columns, inplace=True)

# %%
data.columns.tolist()
# Out:
# ['ID',
#  'age',
#  'gender',
#  'highest_eduction',
#  'land_response',
#  'Q5',
#  'own_land',
#  'own_phone',
#  'Q8_1',
#  'Q8_2',
#  'Q8_3',
#  'Q8_4',
#  'Q8_5',
#  'Q8_6',
#  'Q8_7',
#  'Q8_8',
#  'Q8_9',
#  'Q8_10',
#  'Q8_11',
#  'employer',
#  'goods_sold',
#  'service_provided',
#  'sent_money_outside',
#  'sent_money_last',
#  'recived_money_inlast12months',
#  'last_recieved_money',
#  'purchase_frequency',
#  'bills_frequency',
#  'kiswahili_literacy',
#  'english_literacy',
#  'Latitude',
#  'Longitude',
#  'mobile_money',
#  'savings',
#  'borrowing',
#  'insurance',
#  'mobile_money_classification']

# %%
data.head()
# Out:
#      ID  age  gender  highest_eduction  land_response  Q5  own_land  \
# 0  5086   98       2                 3              1   1         2
# 1  1258   40       1                 1              3   5         1
# 2   331   18       2                 4              6   3         2
# 3  6729   50       1                 1              3   1         1
# 4  8671   34       1                 1              1   1         2
#
#    own_phone  Q8_1  Q8_2  ...  bills_frequency  kiswahili_literacy  \
# 0          2     0     0  ...               -1                   4
# 1          1     1     0  ...                4                   1
# 2          1     0     0  ...               -1                   1
# 3          1     0     0  ...               -1                   1
# 4          1     0     1  ...               -1                   1
#
#    english_literacy  Latitude  Longitude  mobile_money  savings  borrowing  \
# ...

# %% [markdown]
# > Get numeric columns that can be used to plot

# %%
data.describe()
# Out:
#                 ID          age       gender  highest_eduction  land_response  \
# count  7094.000000  7094.000000  7094.000000       7094.000000    7094.000000
# mean   4742.627291    38.239498     1.559910          1.787426       3.060051
# std    2731.120086    16.332148     0.496433          1.165160       1.557779
# min       1.000000    16.000000     1.000000          1.000000       1.000000
# 25%    2397.250000    25.000000     1.000000          1.000000       2.000000
# 50%    4744.500000    35.000000     2.000000          1.000000       3.000000
# 75%    7105.000000    48.000000     2.000000          3.000000       3.000000
# max    9459.000000   100.000000     2.000000          4.000000       8.000000
#
#                 Q5     own_land    own_phone         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# ...

# %% [markdown]
# #### Boxplot

# %%
data.gender.dtype
# Out:
# dtype('int64')

# %%
gender = data.gender.values.tolist()
Longitude = data.Longitude.values.tolist()
data_to_plot= [gender, Longitude]

# %%
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot)
plt.title('Boxplot of Longitude based on gender', fontsize=18)
plt.xlabel('gender',fontsize=15)
plt.ylabel('Longitude',fontsize=15)

## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5)

    
## Custom x-axis labels
ax.set_xticklabels(['Male', 'Female'])
plt.show()

# %% [markdown]
# #### Histogram

# %% [markdown]
# > Age Distribution of responsdents

# %%
age = data.age.values.tolist()

# %%
plt.subplots(figsize=(10,5))
plt.hist(age)
plt.xlabel('Ages',fontsize=13)
plt.ylabel('Frequency',fontsize=13)
plt.title('Age Distribution of Respondents', fontsize=15)
plt.show()

# %% [markdown]
# #### Barcharts

# %%
def gender_rename(x):
    if x == 1:
        x='male'
    elif x==2:
        x='female'
    return x

# %%
data.gender = data.gender.apply(lambda x: gender_rename(x))
data.head()
# Out:
#      ID  age  gender  highest_eduction  land_response  Q5  own_land  \
# 0  5086   98  female                 3              1   1         2
# 1  1258   40    male                 1              3   5         1
# 2   331   18  female                 4              6   3         2
# 3  6729   50    male                 1              3   1         1
# 4  8671   34    male                 1              1   1         2
#
#    own_phone  Q8_1  Q8_2  ...  bills_frequency  kiswahili_literacy  \
# 0          2     0     0  ...               -1                   4
# 1          1     1     0  ...                4                   1
# 2          1     0     0  ...               -1                   1
# 3          1     0     0  ...               -1                   1
# 4          1     0     1  ...               -1                   1
#
#    english_literacy  Latitude  Longitude  mobile_money  savings  borrowing  \
# ...

# %%
gender = data.gender.value_counts()
gender = pd.Series(gender)
gender
# Out:
# female    3972
# male      3122
# Name: gender, dtype: int64

# %%
plt.subplots(figsize=(10,8))
plt.title('Distribution of Respondents Genders', fontsize=18)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Counts' ,fontsize=15)
ax = plt.bar(x= gender.index, height=gender.values)
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
x=data.Latitude.values.tolist()
y = data.Longitude.values.tolist()

# %%
plt.subplots(figsize=(10,8))
plt.title('Scatter Plot of Latitiude and Longitude', fontsize=15)
plt.xlabel('Latitude', fontsize=13)
plt.ylabel('Longitude', fontsize=13)
ax = plt.scatter(x, y, alpha=.5, color='g')
plt.show()
